# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ## test case with actually 2 identical branches

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc 2 identical branches E[1, 2, 2] V[4, 4].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc 1 beefy branch E[1, 4] V[8].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# ## My test sinc function with single branch containing double of average of parameters of 2 visco containing branches

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc_longer E[1, 1, 1] V[1.25, 2.5].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 2] V[3.75].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# ## Search for how different 2 branches must be to produce an obviously recognisable distinction between 1 and 2 branch solutions

# %% [markdown]
# ### Wild order of mag differences

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 1, 10] V[1, 100].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 11] V[101].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# --line--

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 1, 100] V[10, 0.1].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 101] V[10.1].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %% [markdown]
# ### not quite an order of mag, but bigger than double

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 1, 5] V[1, 5].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 6] V[6].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %% [markdown]
# discovered here that the thing that makes teh branches collapse into one branch is if the ratio between teh visc and E is teh same in both branches

# %% [markdown]
# ## Tau differs by factor of 5

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 1, 1] V[1, 5].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 2] V[6].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# ## Tau differs by a factor of 10

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 1, 1] V[1, 10].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 2] V[11].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# ### Tau differs by a factor of 50

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 1, 1] V[1, 50].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 2] V[51].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# ### Tau different by a factor of 3

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 1, 1] V[1, 3].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 2] V[4].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# okay, difference in Tau is bigger makes for better, but what about E....

# %% [markdown]
# ## E ratio testing

# %% [markdown]
# ### Tau ratio 1:50, E ratio 1:10

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 1, 10] V[1, 500].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 11] V[501].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# ## E ratio opposite symmetry

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 10, 1] V[10, 50].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 11] V[60].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])

# %% [markdown]
# ## What I have decided is teh data I will use

# %% [markdown]
# I have decided on these values as I note that:
#
# - The larger teh difference in Tau, teh better
#
# - More highly weighting the faster decay helps account for the difference in magnitude difference caused by the faster decay.
#
# - I want something clean, with values that are easy. have two Taus with an order of mag difference should be sufficent and is a good bench mark. aHaving a weighting of teh same relative difference also amkes sense.

# %%
data_2_branches = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 10, 1] V[10, 10].csv', delimiter=',')
data_1_branch = np.loadtxt('../data/StressStrain/Strain Sinc E[1, 11] V[20].csv', delimiter=',')

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])

# %%
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])

# %%
plt.plot(data_2_branches[:, 0:1], data_2_branches[:, 2:])
plt.plot(data_1_branch[:, 0:1], data_1_branch[:, 2:])
plt.ylim(-5, 5)
# Out:
# (-5, 5)

# %%
plt.plot(data_1_branch[:, 0:1], data_2_branches[:, 2:] - data_1_branch[:, 2:])
